# %% [markdown]
# <a href="https://colab.research.google.com/github/radithyaeka-dev/Pemerograman-Dasar/blob/main/pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "radithya"
umur = 19
jurusan = "TRPE"
semester = 3
matakuliah = 'Pemerograman dasar'
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# radithya
# 19
# TRPE
# 3
# Pemerograman dasar
# False
